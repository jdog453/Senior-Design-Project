# %%
from imutils import paths
import numpy as np
import imutils
import pickle
import cv2
import os, sys

sys.path.append('../utilities')
from alignFaces import *

# %%
data_params = {
    "dataset":"../../facial_recognition_data/faces_dataset/", # path to input directory of faces and images
    "embeddings":"../../output/embeddings.pickle", # path to output of database of facial embeddings
    "detector":"../../facial_detection/models/", # path to OpenCV's deep learning face detector
    "embedding_model":"../models/openface.nn4.small2.v1.t7", # path to OpenCV's deep learning face embedding model
    "confidence":0.6 # min probability to filter weak detections
}

# %%
# load our serialized face detector from disk
print("[INFO] loading face detector...")
protoPath = os.path.sep.join([data_params["detector"], "deploy.prototxt"])
modelPath = os.path.sep.join([data_params["detector"], "res10_300x300_ssd_iter_140000.caffemodel"])
detector = cv2.dnn.readNetFromCaffe(protoPath, modelPath)

# load our serialized face embedding model from disk
print("[INFO] loading face recognizer...")
embedder = cv2.dnn.readNetFromTorch(data_params["embedding_model"])
# Out:
# [INFO] loading face detector...
# [INFO] loading face recognizer...

# %%
# grab the paths to the input images in our dataset
print("[INFO] quantifying faces...")
imagePaths = list(paths.list_images(data_params["dataset"]))
print(*imagePaths, sep="\n")
# initialize our lists of extracted facial embeddings and
# corresponding people names
knownEmbeddings = []
knownNames = []

# initialize the total number of faces processed
total = 0
# Out:
# [INFO] quantifying faces...
# ../../facial_recognition_data/faces_dataset/andrew\frame0.jpg
# ../../facial_recognition_data/faces_dataset/andrew\frame10.jpg
# ../../facial_recognition_data/faces_dataset/andrew\frame100.jpg
# ../../facial_recognition_data/faces_dataset/andrew\frame105.jpg
# ../../facial_recognition_data/faces_dataset/andrew\frame110.jpg
# ../../facial_recognition_data/faces_dataset/andrew\frame115.jpg
# ../../facial_recognition_data/faces_dataset/andrew\frame120.jpg
# ../../facial_recognition_data/faces_dataset/andrew\frame125.jpg
# ../../facial_recognition_data/faces_dataset/andrew\frame130.jpg
# ../../facial_recognition_data/faces_dataset/andrew\frame135.jpg
# ../../facial_recognition_data/faces_dataset/andrew\frame140.jpg
# ../../facial_recognition_data/faces_dataset/andrew\frame145.jpg
# ../../facial_recognition_data/faces_dataset/andrew\frame15.jpg
# ../../facial_recognition_data/faces_dataset/andrew\frame150.jpg
# ../../facial_recognition_data/faces_dataset/andrew\frame155.jpg
# ../../facial_recognition_data/faces_dataset/andrew\frame160.jpg
# ../../facial_recognition_data/faces_dataset/andrew\frame165.jpg
# ../../facial_recognition_data/faces_dataset/andrew\frame170.jpg
# ../../facial_recognition_data/faces_dataset/andrew\frame175.jpg
# ../../facial_recognition_data/faces_dataset/andrew\frame180.jpg
# ../../facial_recognition_data/faces_dataset/andrew\frame185.jpg
# ../../facial_recognition_data/faces_dataset/andrew\frame190.jpg
# ../../facial_recognition_data/faces_dataset/andrew\frame195.jpg
# ../../facial_recognition_data/faces_dataset/andrew\frame20.jpg
# ../../facial_recognition_data/faces_dataset/andrew\frame200.jpg
# ../../facial_recognition_data/faces_dataset/andrew\frame205.jpg
# ../../facial_recognition_data/faces_dataset/andrew\frame210.jpg
# ../../facial_recognition_data/faces_dataset/andrew\frame215.jpg
# ../../facial_recognition_data/faces_dataset/andrew\frame220.jpg
# ../../facial_recognition_data/faces_dataset/andrew\frame225.jpg
# ../../facial_recognition_data/faces_dataset/andrew\frame230.jpg
# ../../facial_recognition_data/faces_dataset/andrew\frame235.jpg
# ../../facial_recognition_data/faces_dataset/andrew\frame240.jpg
# ../../facial_recognition_data/faces_dataset/andrew\frame245.jpg
# ../../facial_recognition_data/faces_dataset/andrew\frame25.jpg
# ../../facial_recognition_data/faces_dataset/andrew\frame250.jpg
# ../../facial_recognition_data/faces_dataset/andrew\frame255.jpg
# ../../facial_recognition_data/faces_dataset/andrew\frame260.jpg
# ../../facial_recognition_data/faces_dataset/andrew\frame265.jpg
# ../../facial_recognition_data/faces_dataset/andrew\frame270.jpg
# ../../facial_recognition_data/faces_dataset/andrew\frame275.jpg
# ../../facial_recognition_data/faces_dataset/andrew\frame280.jpg
# ../../facial_recognition_data/faces_dataset/andrew\frame285.jpg
# ../../facial_recognition_data/faces_dataset/andrew\frame290.jpg
# ../../facial_recognition_data/faces_dataset/andrew\frame295.jpg
# ../../facial_recognition_data/faces_dataset/andrew\frame30.jpg
# ../../facial_recognition_data/faces_dataset/andrew\frame300.jpg
# ../../facial_recognition_data/faces_dataset/andrew\frame305.jpg
# ../../facial_recognition_data/faces_dataset/andrew\frame310.jpg
# ../../facial_recognition_data/faces_dataset/andrew\frame315.jpg
# ../../facial_recognition_data/faces_dataset/andrew\frame320.jpg
# ../../facial_recognition_data/faces_dataset/andrew\frame325.jpg
# ../../facial_recognition_data/faces_dataset/andrew\frame330.jpg
# ../../facial_recognition_data/faces_dataset/andrew\frame335.jpg
# ../../facial_recognition_data/faces_dataset/andrew\frame340.jpg
# ../../facial_recognition_data/faces_dataset/andrew\frame345.jpg
# ../../facial_recognition_data/faces_dataset/andrew\frame35.jpg
# ../../facial_recognition_data/faces_dataset/andrew\frame350.jpg
# ../../facial_recognition_data/faces_dataset/andrew\frame355.jpg
# ../../facial_recognition_data/faces_dataset/andrew\frame360.jpg
# ../../facial_recognition_data/faces_dataset/andrew\frame365.jpg
# ../../facial_recognition_data/faces_dataset/andrew\frame370.jpg
# ../../facial_recognition_data/faces_dataset/andrew\frame375.jpg
# ../../facial_recognition_data/faces_dataset/andrew\frame380.jpg
# ../../facial_recognition_data/faces_dataset/andrew\frame385.jpg
# ../../facial_recognition_data/faces_dataset/andrew\frame390.jpg
# ../../facial_recognition_data/faces_dataset/andrew\frame395.jpg
# ../../facial_recognition_data/faces_dataset/andrew\frame40.jpg
# ../../facial_recognition_data/faces_dataset/andrew\frame400.jpg
# ../../facial_recognition_data/faces_dataset/andrew\frame405.jpg
# ../../facial_recognition_data/faces_dataset/andrew\frame410.jpg
# ../../facial_recognition_data/faces_dataset/andrew\frame415.jpg
# ../../facial_recognition_data/faces_dataset/andrew\frame420.jpg
# ../../facial_recognition_data/faces_dataset/andrew\frame425.jpg
# ../../facial_recognition_data/faces_dataset/andrew\frame430.jpg
# ../../facial_recognition_data/faces_dataset/andrew\frame435.jpg
# ../../facial_recognition_data/faces_dataset/andrew\frame440.jpg
# ../../facial_recognition_data/faces_dataset/andrew\frame445.jpg
# ../../facial_recognition_data/faces_dataset/andrew\frame45.jpg
# ../../facial_recognition_data/faces_dataset/andrew\frame450.jpg
# ../../facial_recognition_data/faces_dataset/andrew\frame455.jpg
# ../../facial_recognition_data/faces_dataset/andrew\frame460.jpg
# ../../facial_recognition_data/faces_dataset/andrew\frame465.jpg
# ../../facial_recognition_data/faces_dataset/andrew\frame470.jpg
# ../../facial_recognition_data/faces_dataset/andrew\frame475.jpg
# ../../facial_recognition_data/faces_dataset/andrew\frame480.jpg
# ../../facial_recognition_data/faces_dataset/andrew\frame485.jpg
# ../../facial_recognition_data/faces_dataset/andrew\frame490.jpg
# ../../facial_recognition_data/faces_dataset/andrew\frame495.jpg
# ../../facial_recognition_data/faces_dataset/andrew\frame5.jpg
# ../../facial_recognition_data/faces_dataset/andrew\frame50.jpg
# ../../facial_recognition_data/faces_dataset/andrew\frame55.jpg
# ../../facial_recognition_data/faces_dataset/andrew\frame60.jpg
# ../../facial_recognition_data/faces_dataset/andrew\frame65.jpg
# ../../facial_recognition_data/faces_dataset/andrew\frame70.jpg
# ../../facial_recognition_data/faces_dataset/andrew\frame75.jpg
# ../../facial_recognition_data/faces_dataset/andrew\frame80.jpg
# ../../facial_recognition_data/faces_dataset/andrew\frame85.jpg
# ../../facial_recognition_data/faces_dataset/andrew\frame90.jpg
# ../../facial_recognition_data/faces_dataset/andrew\frame95.jpg
# ../../facial_recognition_data/faces_dataset/andrew\IMG_1247.jpg
# ../../facial_recognition_data/faces_dataset/andrew\IMG_1248.jpg
# ../../facial_recognition_data/faces_dataset/andrew\IMG_1249.jpg
# ../../facial_recognition_data/faces_dataset/andrew\IMG_1250.jpg
# ../../facial_recognition_data/faces_dataset/andrew\IMG_1251.jpg
# ../../facial_recognition_data/faces_dataset/andrew\IMG_1252.jpg
# ../../facial_recognition_data/faces_dataset/andrew\IMG_1253.jpg
# ../../facial_recognition_data/faces_dataset/andrew\IMG_1254.jpg
# ../../facial_recognition_data/faces_dataset/andrew\IMG_1255.jpg
# ../../facial_recognition_data/faces_dataset/andrew\IMG_1256.jpg
# ../../facial_recognition_data/faces_dataset/andrew\IMG_1257.jpg
# ../../facial_recognition_data/faces_dataset/andrew\IMG_1258.jpg
# ../../facial_recognition_data/faces_dataset/austen\20220111_110913.jpg
# ../../facial_recognition_data/faces_dataset/austen\20220111_110930.jpg
# ../../facial_recognition_data/faces_dataset/austen\20220111_110949.jpg
# ../../facial_recognition_data/faces_dataset/austen\20220111_111003.jpg
# ../../facial_recognition_data/faces_dataset/austen\20220111_111034.jpg
# ../../facial_recognition_data/faces_dataset/austen\20220212_131756.jpg
# ../../facial_recognition_data/faces_dataset/austen\20220212_131813.jpg
# ../../facial_recognition_data/faces_dataset/austen\20220212_131819.jpg
# ../../facial_recognition_data/faces_dataset/austen\20220212_131823.jpg
# ../../facial_recognition_data/faces_dataset/austen\20220212_131829.jpg
# ../../facial_recognition_data/faces_dataset/austen\20220212_131835.jpg
# ../../facial_recognition_data/faces_dataset/austen\20220222_160922.jpg
# ../../facial_recognition_data/faces_dataset/austen\20220222_160929.jpg
# ../../facial_recognition_data/faces_dataset/austen\20220222_160937.jpg
# ../../facial_recognition_data/faces_dataset/austen\20220222_160942.jpg
# ../../facial_recognition_data/faces_dataset/austen\20220222_160954.jpg
# ../../facial_recognition_data/faces_dataset/austen\20220222_161002.jpg
# ../../facial_recognition_data/faces_dataset/austen\20220222_161017.jpg
# ../../facial_recognition_data/faces_dataset/austen\20220222_161034.jpg
# ../../facial_recognition_data/faces_dataset/austen\20220222_161046.jpg
# ../../facial_recognition_data/faces_dataset/austen\20220222_161102.jpg
# ../../facial_recognition_data/faces_dataset/austen\20220222_161110.jpg
# ../../facial_recognition_data/faces_dataset/austen\20220222_161201.jpg
# ../../facial_recognition_data/faces_dataset/austen\frame0.jpg
# ../../facial_recognition_data/faces_dataset/austen\frame105.jpg
# ../../facial_recognition_data/faces_dataset/austen\frame112.jpg
# ../../facial_recognition_data/faces_dataset/austen\frame119.jpg
# ../../facial_recognition_data/faces_dataset/austen\frame126.jpg
# ../../facial_recognition_data/faces_dataset/austen\frame133.jpg
# ../../facial_recognition_data/faces_dataset/austen\frame14.jpg
# ../../facial_recognition_data/faces_dataset/austen\frame140.jpg
# ../../facial_recognition_data/faces_dataset/austen\frame147.jpg
# ../../facial_recognition_data/faces_dataset/austen\frame154.jpg
# ../../facial_recognition_data/faces_dataset/austen\frame161.jpg
# ../../facial_recognition_data/faces_dataset/austen\frame168.jpg
# ../../facial_recognition_data/faces_dataset/austen\frame175.jpg
# ../../facial_recognition_data/faces_dataset/austen\frame182.jpg
# ../../facial_recognition_data/faces_dataset/austen\frame189.jpg
# ../../facial_recognition_data/faces_dataset/austen\frame196.jpg
# ../../facial_recognition_data/faces_dataset/austen\frame203.jpg
# ../../facial_recognition_data/faces_dataset/austen\frame21.jpg
# ../../facial_recognition_data/faces_dataset/austen\frame210.jpg
# ../../facial_recognition_data/faces_dataset/austen\frame217.jpg
# ../../facial_recognition_data/faces_dataset/austen\frame224.jpg
# ../../facial_recognition_data/faces_dataset/austen\frame231.jpg
# ../../facial_recognition_data/faces_dataset/austen\frame238.jpg
# ../../facial_recognition_data/faces_dataset/austen\frame245.jpg
# ../../facial_recognition_data/faces_dataset/austen\frame252.jpg
# ../../facial_recognition_data/faces_dataset/austen\frame259.jpg
# ../../facial_recognition_data/faces_dataset/austen\frame266.jpg
# ../../facial_recognition_data/faces_dataset/austen\frame273.jpg
# ../../facial_recognition_data/faces_dataset/austen\frame28.jpg
# ../../facial_recognition_data/faces_dataset/austen\frame280.jpg
# ../../facial_recognition_data/faces_dataset/austen\frame287.jpg
# ../../facial_recognition_data/faces_dataset/austen\frame294.jpg
# ../../facial_recognition_data/faces_dataset/austen\frame301.jpg
# ../../facial_recognition_data/faces_dataset/austen\frame308.jpg
# ../../facial_recognition_data/faces_dataset/austen\frame315.jpg
# ../../facial_recognition_data/faces_dataset/austen\frame322.jpg
# ../../facial_recognition_data/faces_dataset/austen\frame329.jpg
# ../../facial_recognition_data/faces_dataset/austen\frame336.jpg
# ../../facial_recognition_data/faces_dataset/austen\frame343.jpg
# ../../facial_recognition_data/faces_dataset/austen\frame35.jpg
# ../../facial_recognition_data/faces_dataset/austen\frame350.jpg
# ../../facial_recognition_data/faces_dataset/austen\frame357.jpg
# ../../facial_recognition_data/faces_dataset/austen\frame364.jpg
# ../../facial_recognition_data/faces_dataset/austen\frame371.jpg
# ../../facial_recognition_data/faces_dataset/austen\frame378.jpg
# ../../facial_recognition_data/faces_dataset/austen\frame385.jpg
# ../../facial_recognition_data/faces_dataset/austen\frame392.jpg
# ../../facial_recognition_data/faces_dataset/austen\frame399.jpg
# ../../facial_recognition_data/faces_dataset/austen\frame406.jpg
# ../../facial_recognition_data/faces_dataset/austen\frame413.jpg
# ../../facial_recognition_data/faces_dataset/austen\frame42.jpg
# ../../facial_recognition_data/faces_dataset/austen\frame420.jpg
# ../../facial_recognition_data/faces_dataset/austen\frame427.jpg
# ../../facial_recognition_data/faces_dataset/austen\frame434.jpg
# ../../facial_recognition_data/faces_dataset/austen\frame441.jpg
# ../../facial_recognition_data/faces_dataset/austen\frame448.jpg
# ../../facial_recognition_data/faces_dataset/austen\frame455.jpg
# ../../facial_recognition_data/faces_dataset/austen\frame462.jpg
# ../../facial_recognition_data/faces_dataset/austen\fr
# ../../facial_recognition_data/faces_dataset/unknown\0eef9367ab5e82cd.jpg
# ../../facial_recognition_data/faces_dataset/unknown\0x0.jpg
# ../../facial_recognition_data/faces_dataset/unknown\0_Newcastle-United-v-Tottenham-Hotspur-Premier-League.jpg
# ../../facial_recognition_data/faces_dataset/unknown\1280_kim_kardashian (1).jpg
# ../../facial_recognition_data/faces_dataset/unknown\1629851817710.jpg
# ../../facial_recognition_data/faces_dataset/unknown\1678550_People_Justin_Bieber_79325.-250x250.jpg
# ../../facial_recognition_data/faces_dataset/unknown\180117-celebrity-investments-diddy.jpg
# ../../facial_recognition_data/faces_dataset/unknown\180117-celebrity-investments-reese-witherspoon.jpg
# ../../facial_recognition_data/faces_dataset/unknown\1870_1_HJ-galeri.jpg
# ../../facial_recognition_data/faces_dataset/unknown\1_Ivor-Novello-Awards-2021-Red-Carpet-Arrivals.jpg
# ../../facial_recognition_data/faces_dataset/unknown\1_US-ENTERTAINMENT-SHOWTIME-LOUDEST-VOICE.jpg
# ../../facial_recognition_data/faces_dataset/unknown\52dca903-c7e2-4aa7-a8ff-446507013cfe.jpg
# ../../facial_recognition_data/faces_dataset/unknown\60746ccf3e3fe7001882a1db.jpg
# ../../facial_recognition_data/faces_dataset/unknown\619307-photo-u368.jpg
# ../../facial_recognition_data/faces_dataset/unknown\81W1swVa19L.jpg
# ../../facial_recognition_data/faces_dataset/unknown\89c154_629e352535f74fc8bcca603d0ef6ddee_mv2.jpg
# ../../facial_recognition_data/faces_dataset/unknown\9ZHQZnav64fvNzy8fvgQin.jpg
# ../../facial_recognition_data/faces_dataset/unknown\a1423bf19cae8112.jpg
# ../../facial_recognition_data/faces_dataset/unknown\amanda_bynes.jpg
# ../../facial_recognition_data/faces_dataset/unknown\Ashton Kutcher.jpg
# ../../facial_recognition_data/faces_dataset/unknown\benedict_cumberbatch.jpg
# ../../facial_recognition_data/faces_dataset/unknown\billie_eilish.jpg
# ../../facial_recognition_data/faces_dataset/unknown\blake-lively.jpg
# ../../facial_recognition_data/faces_dataset/unknown\c1d1d99d01af2f3daf660d5b8accb0b9.jpg
# ../../facial_recognition_data/faces_dataset/unknown\Carrie Underwood.jpg
# ../../facial_recognition_data/faces_dataset/unknown\celebrity-short-haircuts-2021-new-6-1200x1714.jpg
# ../../facial_recognition_data/faces_dataset/unknown\CelebritySupporter_JordinSparks.jpg
# ../../facial_recognition_data/faces_dataset/unknown\Channing Tatum.jpg
# ../../facial_recognition_data/faces_dataset/unknown\Chris Evans.jpg
# ../../facial_recognition_data/faces_dataset/unknown\Chris Pratt.jpg
# ../../facial_recognition_data/faces_dataset/unknown\Cobie Smulders.jpg
# ../../facial_recognition_data/faces_dataset/unknown\Danny Masterson.jpg
# ../../facial_recognition_data/faces_dataset/unknown\Dave Bautista.jpg
# ../../facial_recognition_data/faces_dataset/unknown\Dolly Parton.jpg
# ../../facial_recognition_data/faces_dataset/unknown\download.jpg
# ../../facial_recognition_data/faces_dataset/unknown\elizabeth_olsen.jpg
# ../../facial_recognition_data/faces_dataset/unknown\fakesample.jpg
# ../../facial_recognition_data/faces_dataset/unknown\George-W-Bush.jpeg
# ../../facial_recognition_data/faces_dataset/unknown\GettyImages-1135889547.jpg
# ../../facial_recognition_data/faces_dataset/unknown\gettyimages-490703338.jpg
# ../../facial_recognition_data/faces_dataset/unknown\Gwenyth Paltrow.jpg
# ../../facial_recognition_data/faces_dataset/unknown\
jpg
# ../../facial_recognition_data/faces_dataset/unknown\Tom Cruise.jpg
# ../../facial_recognition_data/faces_dataset/unknown\tom_holland.jpg
# ../../facial_recognition_data/faces_dataset/unknown\tonyb.jpg
# ../../facial_recognition_data/faces_dataset/unknown\trump.jpg
# ../../facial_recognition_data/faces_dataset/unknown\untitled-design-27.jpg
# ../../facial_recognition_data/faces_dataset/unknown\will_ferrel.jpg
# ../../facial_recognition_data/faces_dataset/unknown\will_smith.jpg
# ../../facial_recognition_data/faces_dataset/unknown\will_wheaton.jpg
# ../../facial_recognition_data/faces_dataset/unknown\zendaya.jpg
# ../../facial_recognition_data/faces_dataset/unknown\Zoe Saldana.jpg
# ../../facial_recognition_data/faces_dataset/unknown\Zoe%20Kravitz%20at%20The%20Batman%20Screening%20in%20London.jpg
# ../../facial_recognition_data/faces_dataset/unknown\zoe_saldana.jpg

# %%
# loop over the image paths
af = AlignFaces()
for (i, imagePath) in enumerate(imagePaths):
    # extract the person name from the image path
    print("[INFO] processing image {}/{}".format(i + 1, len(imagePaths)))
    # The right side of the last occurance of a '/' character is gotten from the path.
    # Then the string is split based on the '\' character which prepends the image name.
    # The left side of the split, representing the directory/person name is saved as name.
    name = imagePath[imagePath.rindex('/')+1:].split('\\')[0]
    image = cv2.imread(imagePath) # Load the image
    image = af.align_faces(image, imagePath) # Align the image
    if image is None:
        print("[INFO] no face found in image {}".format(i + 1))
        continue
    image = imutils.resize(image, width=600) # Resize the image (while maintaining aspect ratio)
    (h, w) = image.shape[:2] # Grab the image dimensions.
    
    # construct a blob from the image
    imageBlob = cv2.dnn.blobFromImage(
        cv2.resize(image, (300, 300)), 1.0, (300, 300),
        (104.0, 177.0, 123.0), swapRB=False, crop=False)

    # apply OpenCV's deep learning-based face detector to localize
    # faces in the input image
    detector.setInput(imageBlob)
    detections = detector.forward()
    
    # ensure at least one face was found
    if len(detections) > 0:
        # we're making the assumption that each image has only ONE
        # face, so find the bounding box with the largest probability
        i = np.argmax(detections[0, 0, :, 2])
        confidence = detections[0, 0, i, 2]

        # ensure that the detection with the largest probability also
        # means our minimum probability test (thus helping filter out
        # weak detections)
        if confidence > data_params["confidence"]:
            # compute the (x, y)-coordinates of the bounding box for
            # the face
            box = detections[0, 0, i, 3:7] * np.array([w, h, w, h])
            (startX, startY, endX, endY) = box.astype("int")

            # extract the face ROI and grab the ROI dimensions
            face = image[startY:endY, startX:endX]
            (fH, fW) = face.shape[:2]

            # ensure the face width and height are sufficiently large
            if fW < 20 or fH < 20:
                continue
            
            # construct a blob for the face ROI, then pass the blob
            # through our face embedding model to obtain the 128-d
            # quantification of the face
            faceBlob = cv2.dnn.blobFromImage(face, 1.0 / 255,
                (96, 96), (0, 0, 0), swapRB=True, crop=False)
            embedder.setInput(faceBlob)
            vec = embedder.forward()

            # add the name of the person + corresponding face
            # embedding to their respective lists
            knownNames.append(name)
            knownEmbeddings.append(vec.flatten())
            total += 1
# Out:
# [INFO] processing image 1/486
# [INFO] processing image 2/486
# [INFO] processing image 3/486
# [INFO] processing image 4/486
# [INFO] processing image 5/486

# %%
# dump the facial embeddings + names to disk
print("[INFO] serializing {} encodings...".format(total))
data = {"embeddings": knownEmbeddings, "names": knownNames}
f = open(data_params["embeddings"], "wb")
f.write(pickle.dumps(data))
f.close()
