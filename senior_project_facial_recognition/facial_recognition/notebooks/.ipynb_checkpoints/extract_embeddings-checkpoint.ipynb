# %%
from imutils import paths
import numpy as np
import imutils
import pickle
import cv2
import os, sys

sys.path.append('../utilities')
from alignFaces import *

# %%
data_params = {
    "dataset":"../../facial_recognition_data/faces_dataset/", # path to input directory of faces and images
    "embeddings":"../../output/embeddings.pickle", # path to output of database of facial embeddings
    "detector":"../../facial_detection/models/", # path to OpenCV's deep learning face detector
    "embedding_model":"../models/openface.nn4.small2.v1.t7", # path to OpenCV's deep learning face embedding model
    "confidence":0.7 # min probability to filter weak detections
}

# %%
# load our serialized face detector from disk
print("[INFO] loading face detector...")
protoPath = os.path.sep.join([data_params["detector"], "deploy.prototxt"])
modelPath = os.path.sep.join([data_params["detector"], "res10_300x300_ssd_iter_140000.caffemodel"])
detector = cv2.dnn.readNetFromCaffe(protoPath, modelPath)

# load our serialized face embedding model from disk
print("[INFO] loading face recognizer...")
embedder = cv2.dnn.readNetFromTorch(data_params["embedding_model"])
# Out:
# [INFO] loading face detector...
# [INFO] loading face recognizer...

# %%
# grab the paths to the input images in our dataset
print("[INFO] quantifying faces...")
imagePaths = list(paths.list_images(data_params["dataset"]))
print(*imagePaths, sep="\n")
# initialize our lists of extracted facial embeddings and
# corresponding people names
knownEmbeddings = []
knownNames = []

# initialize the total number of faces processed
total = 0
# Out:
# [INFO] quantifying faces...
# ../../facial_recognition_data/faces_dataset/andrew\IMG_1247.jpg
# ../../facial_recognition_data/faces_dataset/andrew\IMG_1248.jpg
# ../../facial_recognition_data/faces_dataset/andrew\IMG_1249.jpg
# ../../facial_recognition_data/faces_dataset/andrew\IMG_1250.jpg
# ../../facial_recognition_data/faces_dataset/andrew\IMG_1251.jpg
# ../../facial_recognition_data/faces_dataset/andrew\IMG_1252.jpg
# ../../facial_recognition_data/faces_dataset/andrew\IMG_1253.jpg
# ../../facial_recognition_data/faces_dataset/andrew\IMG_1254.jpg
# ../../facial_recognition_data/faces_dataset/andrew\IMG_1255.jpg
# ../../facial_recognition_data/faces_dataset/andrew\IMG_1256.jpg
# ../../facial_recognition_data/faces_dataset/andrew\IMG_1257.jpg
# ../../facial_recognition_data/faces_dataset/andrew\IMG_1258.jpg
# ../../facial_recognition_data/faces_dataset/andrew\WIN_20220217_15_22_57_Pro.jpg
# ../../facial_recognition_data/faces_dataset/andrew\WIN_20220217_15_22_58_Pro.jpg
# ../../facial_recognition_data/faces_dataset/andrew\WIN_20220217_15_22_59_Pro.jpg
# ../../facial_recognition_data/faces_dataset/andrew\WIN_20220217_15_23_00_Pro.jpg
# ../../facial_recognition_data/faces_dataset/andrew\WIN_20220217_15_23_02_Pro.jpg
# ../../facial_recognition_data/faces_dataset/andrew\WIN_20220217_15_23_03_Pro.jpg
# ../../facial_recognition_data/faces_dataset/andrew\WIN_20220217_15_23_08_Pro.jpg
# ../../facial_recognition_data/faces_dataset/andrew\WIN_20220217_15_23_09_Pro.jpg
# ../../facial_recognition_data/faces_dataset/andrew\WIN_20220217_15_23_18_Pro.jpg
# ../../facial_recognition_data/faces_dataset/andrew\WIN_20220217_15_23_19_Pro.jpg
# ../../facial_recognition_data/faces_dataset/andrew\WIN_20220217_15_23_21_Pro.jpg
# ../../facial_recognition_data/faces_dataset/austen\20220111_110913.jpg
# ../../facial_recognition_data/faces_dataset/austen\20220111_110930.jpg
# ../../facial_recognition_data/faces_dataset/austen\20220111_110949.jpg
# ../../facial_recognition_data/faces_dataset/austen\20220111_111003.jpg
# ../../facial_recognition_data/faces_dataset/austen\20220111_111034.jpg
# ../../facial_recognition_data/faces_dataset/austen\20220212_131756.jpg
# ../../facial_recognition_data/faces_dataset/austen\20220212_131813.jpg
# ../../facial_recognition_data/faces_dataset/austen\20220212_131819.jpg
# ../../facial_recognition_data/faces_dataset/austen\20220212_131823.jpg
# ../../facial_recognition_data/faces_dataset/austen\20220212_131829.jpg
# ../../facial_recognition_data/faces_dataset/austen\20220212_131835.jpg
# ../../facial_recognition_data/faces_dataset/austen\20220222_160922.jpg
# ../../facial_recognition_data/faces_dataset/austen\20220222_160929.jpg
# ../../facial_recognition_data/faces_dataset/austen\20220222_160937.jpg
# ../../facial_recognition_data/faces_dataset/austen\20220222_160942.jpg
# ../../facial_recognition_data/faces_dataset/austen\20220222_160954.jpg
# ../../facial_recognition_data/faces_dataset/austen\20220222_161002.jpg
# ../../facial_recognition_data/faces_dataset/austen\20220222_161017.jpg
# ../../facial_recognition_data/faces_dataset/austen\20220222_161034.jpg
# ../../facial_recognition_data/faces_dataset/austen\20220222_161046.jpg
# ../../facial_recognition_data/faces_dataset/austen\20220222_161102.jpg
# ../../facial_recognition_data/faces_dataset/austen\20220222_161110.jpg
# ../../facial_recognition_data/faces_dataset/austen\20220222_161201.jpg
# ../../facial_recognition_data/faces_dataset/fred\IMG_4013.jpg
# ../../facial_recognition_data/faces_dataset/fred\IMG_4014.jpg
# ../../facial_recognition_data/faces_dataset/fred\IMG_4015.jpg
# ../../facial_recognition_data/faces_dataset/fred\IMG_4016.jpg
# ../../facial_recognition_data/faces_dataset/fred\IMG_4017.jpg
# ../../facial_recognition_data/faces_dataset/fred\IMG_4018.jpg
# ../../facial_recognition_data/faces_dataset/fred\IMG_4019.jpg
# ../../facial_recognition_data/faces_dataset/fred\IMG_4020.jpg
# ../../facial_recognition_data/faces_dataset/fred\IMG_4021.jpg
# ../../facial_recognition_data/faces_dataset/fred\IMG_4022.jpg
# ../../facial_recognition_data/faces_dataset/fred\IMG_4023.jpg
# ../../facial_recognition_data/faces_dataset/fred\IMG_4041.JPG
# ../../facial_recognition_data/faces_dataset/fred\IMG_4042.JPG
# ../../facial_recognition_data/faces_dataset/fred\IMG_4043.JPG
# ../../facial_recognition_data/faces_dataset/fred\IMG_4044.JPG
# ../../facial_recognition_data/faces_dataset/fred\IMG_4045.JPG
# ../../facial_recognition_data/faces_dataset/fred\IMG_4046.JPG
# ../../facial_recognition_data/faces_dataset/fred\IMG_4047.JPG
# ../../facial_recognition_data/faces_dataset/fred\IMG_4048.JPG
# ../../facial_recognition_data/faces_dataset/fred\IMG_4049.JPG
# ../../facial_recognition_data/faces_dataset/fred\IMG_4050.JPG
# ../../facial_recognition_data/faces_dataset/fred\IMG_4051.JPG
# ../../facial_recognition_data/faces_dataset/fred\IMG_4052.JPG
# ../../facial_recognition_data/faces_dataset/jared\IMG_8774.jpg
# ../../facial_recognition_data/faces_dataset/jared\IMG_8775.jpg
# ../../facial_recognition_data/faces_dataset/jared\IMG_8776.jpg
# ../../facial_recognition_data/faces_dataset/jared\IMG_8777.jpg
# ../../facial_recognition_data/faces_dataset/jared\IMG_8778.jpg
# ../../facial_recognition_data/faces_dataset/jared\IMG_8779.jpg
# ../../facial_recognition_data/faces_dataset/jared\IMG_8780.jpg
# ../../facial_recognition_data/faces_dataset/jared\IMG_8781.jpg
# ../../facial_recognition_data/faces_dataset/jared\IMG_8782.jpg
# ../../facial_recognition_data/faces_dataset/jared\IMG_8783.jpg
# ../../facial_recognition_data/faces_dataset/jared\IMG_8784.jpg
# ../../facial_recognition_data/faces_dataset/jared\IMG_8828.jpg
# ../../facial_recognition_data/faces_dataset/jared\IMG_8829.jpg
# ../../facial_recognition_data/faces_dataset/jared\IMG_8830.jpg
# ../../facial_recognition_data/faces_dataset/jared\IMG_8831.jpg
# ../../facial_recognition_data/faces_dataset/jared\IMG_8832.jpg
# ../../facial_recognition_data/faces_dataset/jared\IMG_8833.jpg
# ../../facial_recognition_data/faces_dataset/jared\IMG_8834.jpg
# ../../facial_recognition_data/faces_dataset/jared\IMG_8835.jpg
# ../../facial_recognition_data/faces_dataset/jared\IMG_8836.jpg
# ../../facial_recognition_data/faces_dataset/jared\IMG_8837.jpg
# ../../facial_recognition_data/faces_dataset/jared\IMG_8838.jpg
# ../../facial_recognition_data/faces_dataset/jared\IMG_8839.jpg
# ../../facial_recognition_data/faces_dataset/unknown\00000.png
# ../../facial_recognition_data/faces_dataset/unknown\00001.png
# ../../facial_recognition_data/faces_dataset/unknown\00002.png
# ../../facial_recognition_data/faces_dataset/unknown\00003.png
# ../../facial_recognition_data/faces_dataset/unknown\00004.png
# ../../facial_recognition_data/faces_dataset/unknown\00005.png
# ../../facial_recognition_data/faces_dataset/unknown\00006.png
# ../../facial_recognition_data/faces_dataset/unknown\00007.png
# ../../facial_recognition_data/faces_dataset/unknown\00008.png
# ../../facial_recognition_data/faces_dataset/unknown\00009.png
# ../../facial_recognition_data/faces_dataset/unknown\00010.png
# ../../facial_recognition_data/faces_dataset/unknown\00011.png
# ../../facial_recognition_data/faces_dataset/unknown\00012.png
# ../../facial_recognition_data/faces_dataset/unknown\00013.png
# ../../facial_recognition_data/faces_dataset/unknown\00014.png
# ../../facial_recognition_data/faces_dataset/unknown\00015.png
# ../../facial_recognition_data/faces_dataset/unknown\00016.png
# ../../facial_recognition_data/faces_dataset/unknown\00017.png
# ../../facial_recognition_data/faces_dataset/unknown\00018.png
# ../../facial_recognition_data/faces_dataset/unknown\00019.png
# ../../facial_recognition_data/faces_dataset/unknown\00020.png
# ../../facial_recognition_data/faces_dataset/unknown\00021.png
# ../../facial_recognition_data/faces_dataset/unknown\00022.png
# ../../facial_recognition_data/faces_dataset/unknown\00023.png
# ../../facial_recognition_data/faces_dataset/unknown\00024.png

# %%
# loop over the image paths
af = AlignFaces()
for (i, imagePath) in enumerate(imagePaths):
    # extract the person name from the image path
    print("[INFO] processing image {}/{}".format(i + 1, len(imagePaths)))
    # The right side of the last occurance of a '/' character is gotten from the path.
    # Then the string is split based on the '\' character which prepends the image name.
    # The left side of the split, representing the directory/person name is saved as name.
    name = imagePath[imagePath.rindex('/')+1:].split('\\')[0]
    image = cv2.imread(imagePath) # Load the image
    image = af.align_faces(image, imagePath) # Align the image
    image = imutils.resize(image, width=600) # Resize the image (while maintaining aspect ratio)
    (h, w) = image.shape[:2] # Grab the image dimensions.
    
    # construct a blob from the image
    imageBlob = cv2.dnn.blobFromImage(
        cv2.resize(image, (300, 300)), 1.0, (300, 300),
        (104.0, 177.0, 123.0), swapRB=False, crop=False)

    # apply OpenCV's deep learning-based face detector to localize
    # faces in the input image
    detector.setInput(imageBlob)
    detections = detector.forward()
    
    # ensure at least one face was found
    if len(detections) > 0:
        # we're making the assumption that each image has only ONE
        # face, so find the bounding box with the largest probability
        i = np.argmax(detections[0, 0, :, 2])
        confidence = detections[0, 0, i, 2]

        # ensure that the detection with the largest probability also
        # means our minimum probability test (thus helping filter out
        # weak detections)
        if confidence > data_params["confidence"]:
            # compute the (x, y)-coordinates of the bounding box for
            # the face
            box = detections[0, 0, i, 3:7] * np.array([w, h, w, h])
            (startX, startY, endX, endY) = box.astype("int")

            # extract the face ROI and grab the ROI dimensions
            face = image[startY:endY, startX:endX]
            (fH, fW) = face.shape[:2]

            # ensure the face width and height are sufficiently large
            if fW < 20 or fH < 20:
                continue
            
            # construct a blob for the face ROI, then pass the blob
            # through our face embedding model to obtain the 128-d
            # quantification of the face
            faceBlob = cv2.dnn.blobFromImage(face, 1.0 / 255,
                (96, 96), (0, 0, 0), swapRB=True, crop=False)
            embedder.setInput(faceBlob)
            vec = embedder.forward()

            # add the name of the person + corresponding face
            # embedding to their respective lists
            knownNames.append(name)
            knownEmbeddings.append(vec.flatten())
            total += 1
# Out:
# [INFO] processing image 1/117
# [INFO] processing image 2/117
# [INFO] processing image 3/117
# [INFO] processing image 4/117
# [INFO] processing image 5/117
# [INFO] processing image 6/117
# [INFO] processing image 7/117
# [INFO] processing image 8/117
# [INFO] processing image 9/117
# [INFO] processing image 10/117
# [INFO] processing image 11/117
# [INFO] processing image 12/117
# [INFO] processing image 13/117
# [INFO] processing image 14/117
