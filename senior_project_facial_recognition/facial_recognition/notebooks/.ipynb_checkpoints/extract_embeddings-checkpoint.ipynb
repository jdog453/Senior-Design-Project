# %%
from imutils import paths
import numpy as np
import imutils
import pickle
import cv2
import os, sys

sys.path.append('../utilities')
from alignFaces import *

# %%
data_params = {
    "dataset":"../../facial_recognition_data/faces_dataset/", # path to input directory of images
    "embeddings":"../../output/embeddings.pickle", # path to output of database of facial embeddings
    "detector":"../../facial_detection/models/", # path to OpenCV's deep learning face detector
    "embedding_model":"../models/openface.nn4.small2.v1.t7", # path to OpenCV's deep learning face embedding model
    "confidence":0.5 # min probability to filter weak detections
}

# %%
# load our serialized face detector from disk
print("[INFO] loading face detector...")
protoPath = os.path.sep.join([data_params["detector"], "deploy.prototxt"])
modelPath = os.path.sep.join([data_params["detector"], "res10_300x300_ssd_iter_140000.caffemodel"])
detector = cv2.dnn.readNetFromCaffe(protoPath, modelPath)

# load our serialized face embedding model from disk
print("[INFO] loading face recognizer...")
embedder = cv2.dnn.readNetFromTorch(data_params["embedding_model"])
# Out:
# [INFO] loading face detector...
# [INFO] loading face recognizer...

# %%
# grab the paths to the input images in our dataset
print("[INFO] quantifying faces...")
imagePaths = list(paths.list_images(data_params["dataset"]))
print(*imagePaths, sep="\n")
# initialize our lists of extracted facial embeddings and
# corresponding people names
knownEmbeddings = []
knownNames = []

# initialize the total number of faces processed
total = 0
# Out:
# [INFO] quantifying faces...
# ../../facial_recognition_data/faces_dataset/andrew\andrew_frame0.jpg
# ../../facial_recognition_data/faces_dataset/andrew\andrew_frame100.jpg
# ../../facial_recognition_data/faces_dataset/andrew\andrew_frame1000.jpg
# ../../facial_recognition_data/faces_dataset/andrew\andrew_frame1020.jpg
# ../../facial_recognition_data/faces_dataset/andrew\andrew_frame1040.jpg
# ../../facial_recognition_data/faces_dataset/andrew\andrew_frame1060.jpg
# ../../facial_recognition_data/faces_dataset/andrew\andrew_frame1080.jpg
# ../../facial_recognition_data/faces_dataset/andrew\andrew_frame1100.jpg
# ../../facial_recognition_data/faces_dataset/andrew\andrew_frame1120.jpg
# ../../facial_recognition_data/faces_dataset/andrew\andrew_frame1140.jpg
# ../../facial_recognition_data/faces_dataset/andrew\andrew_frame1160.jpg
# ../../facial_recognition_data/faces_dataset/andrew\andrew_frame1180.jpg
# ../../facial_recognition_data/faces_dataset/andrew\andrew_frame120.jpg
# ../../facial_recognition_data/faces_dataset/andrew\andrew_frame1200.jpg
# ../../facial_recognition_data/faces_dataset/andrew\andrew_frame1220.jpg
# ../../facial_recognition_data/faces_dataset/andrew\andrew_frame1240.jpg
# ../../facial_recognition_data/faces_dataset/andrew\andrew_frame1260.jpg
# ../../facial_recognition_data/faces_dataset/andrew\andrew_frame1280.jpg
# ../../facial_recognition_data/faces_dataset/andrew\andrew_frame1300.jpg
# ../../facial_recognition_data/faces_dataset/andrew\andrew_frame1320.jpg
# ../../facial_recognition_data/faces_dataset/andrew\andrew_frame1340.jpg
# ../../facial_recognition_data/faces_dataset/andrew\andrew_frame1360.jpg
# ../../facial_recognition_data/faces_dataset/andrew\andrew_frame1380.jpg
# ../../facial_recognition_data/faces_dataset/andrew\andrew_frame140.jpg
# ../../facial_recognition_data/faces_dataset/andrew\andrew_frame160.jpg
# ../../facial_recognition_data/faces_dataset/andrew\andrew_frame180.jpg
# ../../facial_recognition_data/faces_dataset/andrew\andrew_frame20.jpg
# ../../facial_recognition_data/faces_dataset/andrew\andrew_frame200.jpg
# ../../facial_recognition_data/faces_dataset/andrew\andrew_frame220.jpg
# ../../facial_recognition_data/faces_dataset/andrew\andrew_frame240.jpg
# ../../facial_recognition_data/faces_dataset/andrew\andrew_frame260.jpg
# ../../facial_recognition_data/faces_dataset/andrew\andrew_frame280.jpg
# ../../facial_recognition_data/faces_dataset/andrew\andrew_frame300.jpg
# ../../facial_recognition_data/faces_dataset/andrew\andrew_frame320.jpg
# ../../facial_recognition_data/faces_dataset/andrew\andrew_frame340.jpg
# ../../facial_recognition_data/faces_dataset/andrew\andrew_frame360.jpg
# ../../facial_recognition_data/faces_dataset/andrew\andrew_frame380.jpg
# ../../facial_recognition_data/faces_dataset/andrew\andrew_frame40.jpg
# ../../facial_recognition_data/faces_dataset/andrew\andrew_frame400.jpg
# ../../facial_recognition_data/faces_dataset/andrew\andrew_frame420.jpg
# ../../facial_recognition_data/faces_dataset/andrew\andrew_frame440.jpg
# ../../facial_recognition_data/faces_dataset/andrew\andrew_frame460.jpg
# ../../facial_recognition_data/faces_dataset/andrew\andrew_frame480.jpg
# ../../facial_recognition_data/faces_dataset/andrew\andrew_frame500.jpg
# ../../facial_recognition_data/faces_dataset/andrew\andrew_frame520.jpg
# ../../facial_recognition_data/faces_dataset/andrew\andrew_frame540.jpg
# ../../facial_recognition_data/faces_dataset/andrew\andrew_frame560.jpg
# ../../facial_recognition_data/faces_dataset/andrew\andrew_frame580.jpg
# ../../facial_recognition_data/faces_dataset/andrew\andrew_frame60.jpg
# ../../facial_recognition_data/faces_dataset/andrew\andrew_frame600.jpg
# ../../facial_recognition_data/faces_dataset/andrew\andrew_frame620.jpg
# ../../facial_recognition_data/faces_dataset/andrew\andrew_frame640.jpg
# ../../facial_recognition_data/faces_dataset/andrew\andrew_frame660.jpg
# ../../facial_recognition_data/faces_dataset/andrew\andrew_frame680.jpg
# ../../facial_recognition_data/faces_dataset/andrew\andrew_frame700.jpg
# ../../facial_recognition_data/faces_dataset/andrew\andrew_frame720.jpg
# ../../facial_recognition_data/faces_dataset/andrew\andrew_frame740.jpg
# ../../facial_recognition_data/faces_dataset/andrew\andrew_frame760.jpg
# ../../facial_recognition_data/faces_dataset/andrew\andrew_frame780.jpg
# ../../facial_recognition_data/faces_dataset/andrew\andrew_frame80.jpg
# ../../facial_recognition_data/faces_dataset/andrew\andrew_frame800.jpg
# ../../facial_recognition_data/faces_dataset/andrew\andrew_frame820.jpg
# ../../facial_recognition_data/faces_dataset/andrew\andrew_frame840.jpg
# ../../facial_recognition_data/faces_dataset/andrew\andrew_frame860.jpg
# ../../facial_recognition_data/faces_dataset/andrew\andrew_frame880.jpg
# ../../facial_recognition_data/faces_dataset/andrew\andrew_frame900.jpg
# ../../facial_recognition_data/faces_dataset/andrew\andrew_frame920.jpg
# ../../facial_recognition_data/faces_dataset/andrew\andrew_frame940.jpg
# ../../facial_recognition_data/faces_dataset/andrew\andrew_frame960.jpg
# ../../facial_recognition_data/faces_dataset/andrew\andrew_frame980.jpg
# ../../facial_recognition_data/faces_dataset/austen\austen_frame0.jpg
# ../../facial_recognition_data/faces_dataset/austen\austen_frame1007.jpg
# ../../facial_recognition_data/faces_dataset/austen\austen_frame1026.jpg
# ../../facial_recognition_data/faces_dataset/austen\austen_frame1045.jpg
# ../../facial_recognition_data/faces_dataset/austen\austen_frame1064.jpg
# ../../facial_recognition_data/faces_dataset/austen\austen_frame1083.jpg
# ../../facial_recognition_data/faces_dataset/austen\austen_frame1102.jpg
# ../../facial_recognition_data/faces_dataset/austen\austen_frame1121.jpg
# ../../facial_recognition_data/faces_dataset/austen\austen_frame114.jpg
# ../../facial_recognition_data/faces_dataset/austen\austen_frame1140.jpg
# ../../facial_recognition_data/faces_dataset/austen\austen_frame1159.jpg
# ../../facial_recognition_data/faces_dataset/austen\austen_frame1178.jpg
# ../../facial_recognition_data/faces_dataset/austen\austen_frame1197.jpg
# ../../facial_recognition_data/faces_dataset/austen\austen_frame1216.jpg
# ../../facial_recognition_data/faces_dataset/austen\austen_frame1235.jpg
# ../../facial_recognition_data/faces_dataset/austen\austen_frame1254.jpg
# ../../facial_recognition_data/faces_dataset/austen\austen_frame1273.jpg
# ../../facial_recognition_data/faces_dataset/austen\austen_frame1292.jpg
# ../../facial_recognition_data/faces_dataset/austen\austen_frame1311.jpg
# ../../facial_recognition_data/faces_dataset/austen\austen_frame133.jpg
# ../../facial_recognition_data/faces_dataset/austen\austen_frame152.jpg
# ../../facial_recognition_data/faces_dataset/austen\austen_frame171.jpg
# ../../facial_recognition_data/faces_dataset/austen\austen_frame19.jpg
# ../../facial_recognition_data/faces_dataset/austen\austen_frame190.jpg
# ../../facial_recognition_data/faces_dataset/austen\austen_frame209.jpg
# ../../facial_recognition_data/faces_dataset/austen\austen_frame228.jpg
# ../../facial_recognition_data/faces_dataset/austen\austen_frame247.jpg
# ../../facial_recognition_data/faces_dataset/austen\austen_frame266.jpg
# ../../facial_recognition_data/faces_dataset/austen\austen_frame285.jpg
# ../../facial_recognition_data/faces_dataset/austen\austen_frame304.jpg
# ../../facial_recognition_data/faces_dataset/austen\austen_frame323.jpg
# ../../facial_recognition_data/faces_dataset/austen\austen_frame342.jpg
# ../../facial_recognition_data/faces_dataset/austen\austen_frame361.jpg
# ../../facial_recognition_data/faces_dataset/austen\austen_frame38.jpg
# ../../facial_recognition_data/faces_dataset/austen\austen_frame380.jpg
# ../../facial_recognition_data/faces_dataset/austen\austen_frame399.jpg
# ../../facial_recognition_data/faces_dataset/austen\austen_frame418.jpg
# ../../facial_recognition_data/faces_dataset/austen\austen_frame437.jpg
# ../../facial_recognition_data/faces_dataset/austen\austen_frame456.jpg
# ../../facial_recognition_data/faces_dataset/austen\austen_frame475.jpg
# ../../facial_recognition_data/faces_dataset/austen\austen_frame494.jpg
# ../../facial_recognition_data/faces_dataset/austen\austen_frame513.jpg
# ../../facial_recognition_data/faces_dataset/austen\austen_frame532.jpg
# ../../facial_recognition_data/faces_dataset/austen\austen_frame551.jpg
# ../../facial_recognition_data/faces_dataset/austen\austen_frame57.jpg
# ../../facial_recognition_data/faces_dataset/austen\austen_frame570.jpg
# ../../facial_recognition_data/faces_dataset/austen\austen_frame589.jpg
# ../../facial_recognition_data/faces_dataset/austen\austen_frame608.jpg
# ../../facial_recognition_data/faces_dataset/austen\austen_frame627.jpg
# ../../facial_recognition_data/faces_dataset/austen\austen_frame646.jpg
# ../../facial_recognition_data/faces_dataset/austen\austen_frame665.jpg
# ../../facial_recognition_data/faces_dataset/austen\austen_frame684.jpg
# ../../facial_recognition_data/faces_dataset/austen\austen_frame703.jpg
# ../../facial_recognition_data/faces_dataset/austen\austen_frame722.jpg
# ../../facial_recognition_data/faces_dataset/austen\austen_frame741.jpg
# ../../facial_recognition_data/faces_dataset/austen\austen_frame76.jpg
# ../../facial_recognition_data/faces_dataset/austen\austen_frame760.jpg
# ../../facial_recognition_data/faces_dataset/austen\austen_frame779.jpg
# ../../facial_recognition_data/faces_dataset/austen\austen_frame798.jpg
# ../../facial_recognition_data/faces_dataset/austen\austen_frame817.jpg
# ../../facial_recognition_data/faces_dataset/austen\austen_frame836.jpg
# ../../facial_recognition_data/faces_dataset/austen\austen_frame855.jpg
# ../../facial_recognition_data/faces_dataset/austen\austen_frame874.jpg
# ../../facial_recognition_data/faces_dataset/austen\austen_frame893.jpg
# ../../facial_recognition_data/faces_dataset/austen\austen_frame912.jpg
# ../../facial_recognition_data/faces_dataset/austen\austen_frame931.jpg
# ../../facial_recognition_data/faces_dataset/austen\austen_frame95.jpg
# ../../facial_recognition_data/faces_dataset/austen\austen_frame950.jpg
# ../../facial_recognition_data/faces_dataset/austen\austen_frame969.jpg
# ../../facial_recognition_data/faces_dataset/austen\austen_frame988.jpg
# ../../facial_recognition_data/faces_dataset/fred\fred_frame0.jpg
# ../../facial_recognition_data/faces_dataset/fred\fred_frame1008.jpg
# ../../facial_recognition_data/faces_dataset/fred\fred_frame1032.jpg
# ../../facial_recognition_data/faces_dataset/fred\fred_frame1056.jpg
# ../../facial_recognition_data/faces_dataset/fred\fred_frame1080.jpg
# ../../facial_recognition_data/faces_dataset/fred\fred_frame1104.jpg
# ../../facial_recognition_data/faces_dataset/fred\fred_frame1128.jpg
# ../../facial_recognition_data/faces_dataset/fred\fred_frame1152.jpg
# ../../facial_recognition_data/faces_dataset/fred\fred_frame1176.jpg
# ../../facial_recognition_data/faces_dataset/fred\fred_frame120.jpg
# ../../facial_recognition_data/faces_dataset/fred\fred_frame1200.jpg
# ../../facial_recognition_data/faces_dataset/fred\fred_frame1224.jpg
# ../../facial_recognition_data/faces_dataset/fred\fred_frame1248.jpg
# ../../facial_recognition_data/faces_dataset/fred\fred_frame1272.jpg
# ../../facial_recognition_data/faces_dataset/fred\fred_frame1296.jpg
# ../../facial_recognition_data/faces_dataset/fred\fred_frame1320.jpg
# ../../facial_recognition_data/faces_dataset/fred\fred_frame1344.jpg
# ../../facial_recognition_data/faces_dataset/fred\fred_frame1368.jpg
# ../../facial_recognition_data/faces_dataset/fred\fred_frame1392.jpg
# ../../facial_recognition_data/faces_dataset/fred\fred_frame1416.jpg
# ../../facial_recognition_data/faces_dataset/fred\fred_frame144.jpg
# ../../facial_recognition_data/faces_dataset/fred\fred_frame1440.jpg
# ../../facial_recognition_data/faces_dataset/fred\fred_frame1464.jpg
# ../../facial_recognition_data/faces_dataset/fred\fred_frame1488.jpg
# ../../facial_recognition_data/faces_dataset/fred\fred_frame1512.jpg
# ../../facial_recognition_data/faces_dataset/fred\fred_frame1536.jpg
# ../../facial_recognition_data/faces_dataset/fred\fred_frame1560.jpg
# ../../facial_recognition_data/faces_dataset/fred\fred_frame1584.jpg
# ../../facial_recognition_data/faces_dataset/fred\fred_frame1608.jpg
# ../../facial_recognition_data/faces_dataset/fred\fred_frame1632.jpg
# ../../facial_recognition_data/faces_dataset/fred\fred_frame1656.jpg
# ../../facial_recognition_data/faces_dataset/fred\fred_frame168.jpg
# ../../facial_recognition_data/faces_dataset/fred\fred_frame192.jpg
# ../../facial_recognition_data/faces_dataset/fred\fred_frame216.jpg
# ../../facial_recognition_data/faces_dataset/fred\fred_frame24.jpg
# ../../facial_recognition_data/faces_dataset/fred\fred_frame240.jpg
# ../../facial_recognition_data/faces_dataset/fred\fred_frame264.jpg
# ../../facial_recognition_data/faces_dataset/fred\fred_frame288.jpg
# ../../facial_recognition_data/faces_dataset/fred\fred_frame312.jpg
# ../../facial_recognition_data/faces_dataset/fred\fred_frame336.jpg
# ../../facial_recognition_data/faces_dataset/fred\fred_frame360.jpg
# ../../facial_recognition_data/faces_dataset/fred\fred_frame384.jpg
# ../../facial_recognition_data/faces_dataset/fred\fred_frame408.jpg
# ../../facial_recognition_data/faces_dataset/fred\fred_frame432.jpg
# ../../facial_recognition_data/faces_dataset/fred\fred_frame456.jpg
# ../../facial_recognition_data/faces_dataset/fred\fred_frame48.jpg
# ../../facial_recognition_data/faces_dataset/fred\fred_frame480.jpg
# ../../facial_recognition_data/faces_dataset/fred\fred_frame504.jpg
# ../../facial_recognition_data/faces_dataset/fred\fred_frame528.jpg
# ../../facial_recognition_data/faces_dataset/fred\fred_frame552.jpg
# ../../facial_recognition_data/faces_dataset/fred\fred_frame576.jpg
# ../../facial_recognition_data/faces_dataset/fred\fred_frame600.jpg
# ../../facial_recognition_data/faces_dataset/fred\fred_frame624.jpg
# ../../facial_recognition_data/faces_dataset/fred\fred_frame648.jpg
# ../../facial_recognition_data/faces_dataset/fred\fred_frame672.jpg
# ../../facial_recognition_data/faces_dataset/fred\fred_frame696.jpg
# ../../facial_recognition_data/faces_dataset/fred\fred_frame72.jpg
# ../../facial_recognition_data/faces_dataset/fred\fred_frame720.jpg
# ../../facial_recognition_data/faces_dataset/fred\fred_frame744.jpg
# ../../facial_recognition_data/faces_dataset/fred\fred_frame768.jpg
# ../../facial_recognition_data/faces_dataset/fred\fred_frame792.jpg
# ../../facial_recognition_data/faces_dataset/fred\fred_frame816.jpg
# ../../facial_recognition_data/faces_dataset/fred\fred_frame840.jpg
# ../../facial_recognition_data/faces_dataset/fred\fred_frame864.jpg
# ../../facial_recognition_data/faces_dataset/fred\fred_frame888.jpg
# ../../facial_recognition_data/faces_dataset/fred\fred_frame912.jpg
# ../../facial_recognition_data/faces_dataset/fred\fred_frame936.jpg
# ../../facial_recognition_data/faces_dataset/fred\fred_frame96.jpg
# ../../facial_recognition_data/faces_dataset/fred\fred_frame960.jpg
# ../../facial_recognition_data/faces_dataset/fred\fred_frame984.jpg
# ../../facial_recognition_data/faces_dataset/unknown\000001.jpg
# ../../facial_recognition_data/faces_dataset/unknown\000002.jpg
# ../../facial_recognition_data/faces_dataset/unknown\000003.jpg
# ../../facial_recognition_data/faces_dataset/unknown\000004.jpg
# ../../facial_recognition_data/faces_dataset/unknown\000005.jpg
# ../../facial_recognition_data/faces_dataset/unknown\000006.jpg
# ../../facial_recognition_data/faces_dataset/unknown\000007.jpg
# ../../facial_recognition_data/faces_dataset/unknown\000008.jpg
# ../../facial_recognition_data/faces_dataset/unknown\000009.jpg
# ../../facial_recognition_data/faces_dataset/unknown\000010.jpg
# ../../facial_recognition_data/faces_dataset/unknown\000011.jpg
# ../../facial_recognition_data/faces_dataset/unknown\000012.jpg
# ../../facial_recognition_data/faces_dataset/unknown\000013.jpg
# ../../facial_recognition_data/faces_dataset/unknown\000014.jpg
# ../../facial_recognition_data/faces_dataset/unknown\000015.jpg
# ../../facial_recognition_data/faces_dataset/unknown\000016.jpg
# ../../facial_recognition_data/faces_dataset/unknown\000017.jpg
# ../../facial_recognition_data/faces_dataset/unknown\000018.jpg
# ../../facial_recognition_data/faces_dataset/unknown\000019.jpg
# ../../facial_recognition_data/faces_dataset/unknown\000020.jpg
# ../../facial_recognition_data/faces_dataset/unknown\000021.jpg
# ../../facial_recognition_data/faces_dataset/unknown\000022.jpg
# ../../facial_recognition_data/faces_dataset/unknown\000023.jpg
# ../../facial_recognition_data/faces_dataset/unknown\000024.jpg
# ../../facial_recognition_data/faces_dataset/unknown\000025.jpg
# ../../facial_recognition_data/faces_dataset/unknown\000026.jpg
# ../../facial_recognition_data/faces_dataset/unknown\000027.jpg
# ../../facial_recognition_data/faces_dataset/unknown\000028.jpg
# ../../facial_recognition_data/faces_dataset/unknown\000029.jpg
# ../../facial_recognition_data/faces_dataset/unknown\000030.jpg
# ../../facial_recognition_data/faces_dataset/unknown\000031.jpg
# ../../facial_recognition_data/faces_dataset/unknown\000032.jpg
# ../../facial_recognition_data/faces_dataset/unknown\000033.jpg
# ../../facial_recognition_data/faces_dataset/unknown\000034.jpg
# ../../facial_recognition_data/faces_dataset/unknown\000035.jpg
# ../../facial_recognition_data/faces_dataset/unknown\000036.jpg
# ../../facial_recognition_data/faces_dataset/unknown\000037.jpg
# ../../facial_recognition_data/faces_dataset/unknown\000038.jpg
# ../../facial_recognition_data/faces_dataset/unknown\000039.jpg
# ../../facial_recognition_data/faces_dataset/unknown\000040.jpg
# ../../facial_recognition_data/faces_dataset/unknown\000041.jpg
# ../../facial_recognition_data/faces_dataset/unknown\000042.jpg
# ../../facial_recognition_data/faces_dataset/unknown\000043.jpg
# ../../facial_recognition_data/faces_dataset/unknown\000044.jpg
# ../../facial_recognition_data/faces_dataset/unknown\000045.jpg
# ../../facial_recognition_data/faces_dataset/unknown\000046.jpg
# ../../facial_recognition_data/faces_dataset/unknown\000047.jpg
# ../../facial_recognition_data/faces_dataset/unknown\000048.jpg
# ../../facial_recognition_data/faces_dataset/unknown\000049.jpg
# ../../facial_recognition_data/faces_dataset/unknown\000050.jpg
# ../../facial_recognition_data/faces_dataset/unknown\000051.jpg
# ../../facial_recognition_data/faces_dataset/unknown\000052.jpg
# ../../facial_recognition_data/faces_dataset/unknown\000053.jpg
# ../../facial_recognition_data/faces_dataset/unknown\000054.jpg
# ../../facial_recognition_data/faces_dataset/unknown\000055.jpg
# ../../facial_recognition_data/faces_dataset/unknown\000056.jpg
# ../../facial_recognition_data/faces_dataset/unknown\000057.jpg
# ../../facial_recognition_data/faces_dataset/unknown\000058.jpg
# ../../facial_recognition_data/faces_dataset/unknown\000059.jpg
# ../../facial_recognition_data/faces_dataset/unknown\000060.jpg
# ../../facial_recognition_data/faces_dataset/unknown\000061.jpg
# ../../facial_recognition_data/faces_dataset/unknown\000062.jpg
# ../../facial_recognition_data/faces_dataset/unknown\000063.jpg
# ../../facial_recognition_data/faces_dataset/unknown\000064.jpg
# ../../facial_recognition_data/faces_dataset/unknown\000065.jpg
# ../../facial_recognition_data/faces_dataset/unknown\000066.jpg
# ../../facial_recognition_data/faces_dataset/unknown\000067.jpg
# ../../facial_recognition_data/faces_dataset/unknown\000068.jpg
# ../../facial_recognition_data/faces_dataset/unknown\000069.jpg
# ../../facial_recognition_data/faces_dataset/unknown\000070.jpg

# %%
# loop over the image paths
af = AlignFaces()
for (i, imagePath) in enumerate(imagePaths):
    print("[INFO] processing image {}/{}".format(i + 1, len(imagePaths)))
    # The right side of the last occurance of a '/' character is gotten from the path.
    # Then the string is split based on the '\' character which prepends the image name.
    # The left side of the split, representing the directory/person name is saved as name.
    name = imagePath[imagePath.rindex('/')+1:].split('\\')[0]
    
    image = cv2.imread(imagePath) # Load the image
    image = af.align_faces(image) # Align the image.
    (h, w) = image.shape[:2] # Grab the image dimensions.
    
    # construct a blob from the image
    imageBlob = cv2.dnn.blobFromImage(
        cv2.resize(image, (300, 300)), 1.0, (300, 300),
        (104.0, 177.0, 123.0), swapRB=False, crop=False)

    # apply OpenCV's deep learning-based face detector to localize faces in the input image
    detector.setInput(imageBlob)
    detections = detector.forward()
    
    # If at least one face was found, then we continue. Else, we begin the loop once more.
    if len(detections) > 0:
        if len(detections) > 1:
            print("[INFO] {} detections found in image.".format(len(detections)))
        
        # We assume that each image has only ONE face, so find the bounding box with the largest probability
        i = np.argmax(detections[0, 0, :, 2])
        confidence = detections[0, 0, i, 2]

        # The detection with the largest probability is compared against our minimum probability
        # This helps filter out weak detections
        if confidence > data_params["confidence"]:
            # The (x, y)-coordinates of the bounding box for the face are calculated
            box = detections[0, 0, i, 3:7] * np.array([w, h, w, h])
            (startX, startY, endX, endY) = box.astype("int")

            # The face region of interest (ROI) is extracted
            face = image[startY:endY, startX:endX]
            (fH, fW) = face.shape[:2]

            # If the face's width and height are too small, we begin the loop once more.
            if fW < 20 or fH < 20:
                continue
            
            # A blob is constructed for the face ROI. This is then passed
            # through our face embedding model to obtain the 128-d quantification of the face
            faceBlob = cv2.dnn.blobFromImage(face, 1.0 / 255,
                (96, 96), (0, 0, 0), swapRB=True, crop=False)
            embedder.setInput(faceBlob)
            vec = embedder.forward()

            # add the name of the person + corresponding face
            # embedding to their respective lists
            knownNames.append(name)
            knownEmbeddings.append(vec.flatten())
            total += 1
# Out:
# [INFO] processing image 1/280
# [INFO] processing image 2/280
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-20b28bbb0ebb> in <module>
#       9
#      10     image = cv2.imread(imagePath) # Load the image
# ---> 11     image = af.align_faces(image) # Align the image.
#      12     (h, w) = image.shape[:2] # Grab the image dimensions.
#      13
#
# D:\abrow\Senior-Design-Project\senior_project_facial_recognition\facial_recognition\notebooks\../utilities\alignFaces.py in align_faces(self, image)
#      20
#      21         # Each rect represents the coordinates of a detected face's bounding box.
# ---> 22         rects = self.detector(gray, 2)
#      23
#      24         if len(rects) > 1:
#
# KeyboardInterrupt:

# %%
# dump the facial embeddings + names to disk
print("[INFO] serializing {} encodings...".format(total))
data = {"embeddings": knownEmbeddings, "names": knownNames}
f = open(data_params["embeddings"], "wb")
f.write(pickle.dumps(data))
f.close()
